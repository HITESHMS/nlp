# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      |████████████████████████████████| 12.0 MB 5.1 MB/s
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
import spacy
sp = spacy.load('en_core_web_sm')
sen = sp(u"driven")
print("Morphological Analysis for {} = {} + {} + {} " .format(sen.text,sen[0].lemma_,
sen[0].pos_,spacy.explain(sen[0].tag_)))
# Out:
# Morphological Analysis for driven = drive + VERB + verb, past participle

# %%
import spacy
sp = spacy.load('en_core_web_sm')
sen = sp(u"caught")
print("Morphological Analysis for {} = {} + {} + {} " .format(sen.text,sen[0].lemma_,
sen[0].pos_,spacy.explain(sen[0].tag_)))
# Out:
# Morphological Analysis for caught = catch + VERB + verb, past participle

# %%
import spacy
sp = spacy.load('en_core_web_sm')
sen = sp(u"thought")
print("Morphological Analysis for {} = {} + {} + {} " .format(sen.text,sen[0].lemma_,
sen[0].pos_,spacy.explain(sen[0].tag_)))
# Out:
# Morphological Analysis for thought = thought + NOUN + noun, singular or mass

# %%
import spacy
sp = spacy.load('en_core_web_sm')
sen = sp(u"told")
print("Morphological Analysis for {} = {} + {} + {} " .format(sen.text,sen[0].lemma_,
sen[0].pos_,spacy.explain(sen[0].tag_)))
# Out:
# Morphological Analysis for told = tell + VERB + verb, past tense
